# %% [markdown]
# # Problem statement

# %% [raw]
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# -- Input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, and Errors
#
# -- Output: Number of predicted wins (W) ---> considered as target variable for prediction
#
# By the problem statement we have to predict the number of wins so lets do Linear regression

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Import the dataset

# %%
#loading the baseball dataset
data = pd.read_csv("baseball.csv")

# %%
data.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
#printing the shape and information of data
print("shape of the data is", data.shape)
print('\n')
print("information of data", data.info())
# Out:
# shape of the data is (30, 17)
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB
# information of data None

# %% [raw]
# BY seeing the data we can say that there is no categorical data in the data set there is no much preprocessing we can do, so lets continue with the Exploratory data analysis

# %% [markdown]
# # Exploratory Data Analysis

# %%
#lets check if there are null values in the dataset
data.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [raw]
# there is no null values in the data so, lets check the correlation of the datset

# %% [markdown]
# # Correlation

# %%
#this is correlation matrix, which basically shows the correlation betwen any two variables
#lets plot this using heatmap to gain more onsight of data
data.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
#plotting correlation of dataset using heatmap
plt.figure(figsize=(15,10))
sns.heatmap(data.corr(), annot = True)

# %% [raw]
# This plot is mainly useful for checking the correlation betwen variables for eg:there os high positive correlation between ER(Earned runs) and RA(runs allowed) of 0.99 and ERA(Earned runs average) and RA(runs allowed) of 0.99 percent
# there is also negitive correlation in the data betwen RA(runs allowed) and W(wins) of -0.81 so,
# lets define a function to make a list of both positievely and negitively correlated values

# %%
#creating function to find correlatedd columns
def correlation(dataset, threshold):
    corr_set = set()
    corr_mat = data.corr()
    for i in range(len(corr_mat.columns)):
        for j in range(i):
            if abs(corr_mat.iloc[i, j] > threshold):
                colname = corr_mat.columns[i]
                corr_set.add(colname)
    return corr_set
features = correlation(data, 0.90)
print(features)
# Out:
# {'ERA', 'ER'}

# %% [raw]
# After creating a function to find correlation and setting the threshold, that function has returned two fretures
# {'ERA', 'ER'}, actually we can drop there columns but dropping wont do any good due to dropping columns may also affect the accuracy of model

# %% [markdown]
# # Outliers

# %%
#checking the statistical data to know about mean ,std, and percentile.
data.describe().T
# Out:
#      count         mean         std      min        25%       50%      75%  \
# W     30.0    80.966667   10.453455    63.00    74.0000    81.000    87.75
# R     30.0   688.233333   58.761754   573.00   651.2500   689.000   718.25
# AB    30.0  5516.266667   70.467372  5385.00  5464.0000  5510.000  5570.00
# H     30.0  1403.533333   57.140923  1324.00  1363.0000  1382.500  1451.50
# 2B    30.0   274.733333   18.095405   236.00   262.2500   275.500   288.75
# 3B    30.0    31.300000   10.452355    13.00    23.0000    31.000    39.00
# HR    30.0   163.633333   31.823309   100.00   140.2500   158.500   177.00
# BB    30.0   469.100000   57.053725   375.00   428.2500   473.000   501.25
# SO    30.0  1248.200000  103.759470   973.00  1157.5000  1261.500  1311.50
# SB    30.0    83.500000   22.815225    44.00    69.0000    83.500    96.50
# RA    30.0   688.233333   72.108005   525.00   636.2500   695.500   732.50
# ...

# %%
#In machine learning outlier detection is most important for building an accutate model to get good results
#lets create a function that deals with checking outliers
def plotingvariables(df, column):
    plt.figure(figsize=(16,4))
    plt.subplot(1,2,1)
    plt.hist(df[column], alpha = 0.5)
    plt.title(column)

    plt.subplot(1,2,2)
    plt.boxplot(df[column])
    plt.show()

# %%
for i in data:
    plotingvariables(data, i)

# %% [raw]
# we are checking for outliers with histpot and box plot most of the columns dont have outliers we will handle other columns those are with outliers

# %% [raw]
# I guess there is no need to handle these outliers,we can proceed with EDA

# %%
sns.pairplot(data)

# %%
data.plot(kind = 'density', subplots = True, layout = (6,11), sharex = False, legend = False, fontsize = 1, figsize = (18,12))
plt.show()

# %%
#plotting a scatter plot againt targert variable (W)Wins
[(sns.scatterplot(x = i, y = "W", data = data),plt.show()) for i in data]
# Out:
# [(<matplotlib.axes._subplots.AxesSubplot at 0x7f2fda7fed10>, None),
#  (<matplotlib.axes._subplots.AxesSubplot at 0x7f2fd2f44f90>, None),
#  (<matplotlib.axes._subplots.AxesSubplot at 0x7f2fd3426850>, None),
#  (<matplotlib.axes._subplots.AxesSubplot at 0x7f2fd2f66810>, None),
#  (<matplotlib.axes._subplots.AxesSubplot at 0x7f2fd3343e50>, None),
#  (<matplotlib.axes._subplots.AxesSubplot at 0x7f2fd749b950>, None),
#  (<matplotlib.axes._subplots.AxesSubplot at 0x7f2fd31bff50>, None),
#  (<matplotlib.axes._subplots.AxesSubplot at 0x7f2fd317fb90>, None),
#  (<matplotlib.axes._subplots.AxesSubplot at 0x7f2fd3125e50>, None),
#  (<matplotlib.axes._subplots.AxesSubplot at 0x7f2fd30e5b10>, None),
#  (<matplotlib.axes._subplots.AxesSubplot at 0x7f2fd305ce10>, None),
#  (<matplotlib.axes._subplots.AxesSubplot at 0x7f2fd30fbd50>, None),
#  (<matplotlib.axes._subplots.AxesSubplot at 0x7f2fd2e79150>, None),
#  (<matplotlib.axes._subplots.AxesSubplot at 0x7f2fd2e5c890>, None),
# ...

# %%
[(plt.figure(figsize=[20,8]),sns.countplot(data[i]), plt.subplots_adjust(bottom = 0.25), plt.show()) for i in data]
# Out:
# [(<Figure size 1440x576 with 1 Axes>,
# ...
#   None,
#   None),
#  (<Figure size 1440x576 with 1 Axes>,
# ...
#   None,
#   None),
#  (<Figure size 1440x576 with 1 Axes>,
# ...
#   None,
#   None),
#  (<Figure size 1440x576 with 1 Axes>,
# ...
#   None,
#   None),
#  (<Figure size 1440x576 with 1 Axes>,
# ...
#   None,
#   None),
#  (<Figure size 1440x576 with 1 Axes>,
# ...
#   None,
#   None),
#  (<Figure size 1440x576 with 1 Axes>,
# ...
#   None,
#   None),
#  (<Figure size 1440x576 with 1 Axes>,
# ...
#   None,
#   None),
#  (<Figure size 1440x576 with 1 Axes>,
# ...
#   None,
#   None),
#  (<Figure size 1440x576 with 1 Axes>,
# ...
#   None,
#   None),
#  (<Figure size 1440x576 with 1 Axes>,
# ...
#   None,
#   None),
#  (<Figure size 1440x576 with 1 Axes>,
# ...
#   None,
#   None),
#  (<Figure size 1440x576 with 1 Axes>,
# ...
#   None,
#   None),
#  (<Figure size 1440x576 with 1 Axes>,
# ...
#   None,
#   None),
#  (<Figure size 1440x576 with 1 Axes>,
# ...
#   None,
#   None),
#  (<Figure size 1440x576 with 1 Axes>,
# ...
#   None,
#   None),
# ...

# %%
data.hist(figsize=[20,8])
plt.subplots_adjust(bottom = 0.25)
plt.show()

# %% [markdown]
# # Seperating independent variable and target variables

# %%
#seperating independent variables and target variable
x = data.drop(["W"], axis = 1)
y = data["W"]
print(x.shape,y.shape)
# Out:
# (30, 16) (30,)

# %%
from sklearn.preprocessing import RobustScaler
scalar = RobustScaler()
mine = pd.DataFrame(scalar.fit_transform(x), columns=x.columns)
x = mine

# %%
#Scale the data
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
new = pd.DataFrame(scale.fit_transform(x), columns= x.columns)
x = new

# %%
#now lets check the skewness of data
x.skew()
[(sns.distplot(x[i]), plt.show()) for i in x]
# Out:
# [(<matplotlib.axes._subplots.AxesSubplot at 0x7f2fd34d7290>, None),
#  (<matplotlib.axes._subplots.AxesSubplot at 0x7f2fd18059d0>, None),
#  (<matplotlib.axes._subplots.AxesSubplot at 0x7f2fd36ea390>, None),
#  (<matplotlib.axes._subplots.AxesSubplot at 0x7f2fd82260d0>, None),
#  (<matplotlib.axes._subplots.AxesSubplot at 0x7f2fd74a0050>, None),
#  (<matplotlib.axes._subplots.AxesSubplot at 0x7f2fd34eb890>, None),
#  (<matplotlib.axes._subplots.AxesSubplot at 0x7f2fd36262d0>, None),
#  (<matplotlib.axes._subplots.AxesSubplot at 0x7f2fd34fb190>, None),
#  (<matplotlib.axes._subplots.AxesSubplot at 0x7f2fd363a490>, None),
#  (<matplotlib.axes._subplots.AxesSubplot at 0x7f2fd75777d0>, None),
#  (<matplotlib.axes._subplots.AxesSubplot at 0x7f2fd75a9a50>, None),
#  (<matplotlib.axes._subplots.AxesSubplot at 0x7f2fd7632a50>, None),
#  (<matplotlib.axes._subplots.AxesSubplot at 0x7f2fd8011450>, None),
#  (<matplotlib.axes._subplots.AxesSubplot at 0x7f2fd35912d0>, None),
# ...

# %% [raw]
# there is no much skewness so no need to transform it to Normal distribution

# %%
# checking the distplot of whole data
sns.distplot(x)

# %% [markdown]
# # Model creation

# %%
#importing necessary libraries
from sklearn.model_selection import train_test_split, KFold, cross_val_score,GridSearchCV
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from math import sqrt

# %%
#spliting into test data and train data
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size = 0.05, random_state = 100)
print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)
# Out:
# (28, 16) (28,) (2, 16) (2,)

# %%
#now checking the cross_val_score of models to get the best model 
models = []
models.append(('LR', LinearRegression()))
models.append(('L', Lasso()))
models.append(('R', Ridge()))
models.append(('DEC', DecisionTreeRegressor()))
models.append(('KNN', KNeighborsRegressor()))
models.append(('SVC', SVR()))
models.append(('RAN', RandomForestRegressor()))
models.append(('ADA', AdaBoostRegressor()))

results = []
names = []

for name, model in models:
    kfold = KFold(n_splits=10, random_state=100)
    cv_results = cross_val_score(model, x_train, y_train, cv=kfold, scoring='r2')
    
    results.append(cv_results)
    names.append(name)
    
    msg = '%s: %f, %f' % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# LR: -0.314939, 1.654524
# L: 0.558215, 0.320575
# R: 0.337953, 0.634631
# DEC: -1.990095, 3.321168
# KNN: 0.267431, 0.886137
# SVC: -0.477280, 0.776322
# RAN: -0.186937, 1.559516
# ADA: -0.341745, 1.830843

# %%
l = Lasso()
r = Ridge()

# %%
model = []
model.append(('lasso', Lasso()))
model.append(('ridge', Ridge()))

for n,m in model:
    m.fit(x_train,y_train)
    print(m.score(x_train,y_train))
    prediction = m.predict(x_test)
    print("score of ",n,"is:", m.score(x_train,y_train)*100)
    print("MSE :",mean_squared_error(y_test, prediction))
    print("MAE :",mean_absolute_error(y_test, prediction))
    print("RMSE:", sqrt(mean_squared_error(y_test, prediction)))
    print('\n')
# Out:
# 0.8866819104576396
# score of  lasso is: 88.66819104576396
# MSE : 0.7557506089852732
# MAE : 0.6321168354492386
# RMSE: 0.8693391794836313
#
#
# 0.9414766439331914
# score of  ridge is: 94.14766439331915
# MSE : 12.519777906214063
# MAE : 3.2590474992475293
# RMSE: 3.5383298187441574

# %% [raw]
# we have two models with good score and we will pick a model with low RMSE and we have Lasso regression with low RMSE.So we are picking it

# %% [markdown]
# # Saving the model

# %%
#saving the model
import joblib
joblib.dump(l, "Lassobestmodel.obj")
# Out:
# ['Lassobestmodel.obj']

# %%
#loading the model
model1 = joblib.load("Lassobestmodel.obj")

# %% [markdown]
# # Conclusion

# %%
a = np.array(y_test)
l.fit(x_train,y_train)
predicted = l.predict(x_test)
submission = pd.DataFrame({'original' : a, 'predicted' : predicted})

# %%
submission
# Out:
#    original  predicted
# 0        78  79.228924
# 1        84  83.964690

# %% [raw]
# There is a bit of overfitting in the model but by far this is the best model we achieved

# %% [markdown]
#   #           Small Data Is Just Another Challenge That You Can Overcome!
