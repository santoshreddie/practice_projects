# %% [markdown]
# # Getting Started

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("happiness_score_dataset.csv")

# %%
data
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# As we can see that the data has 158 rows and 122 columns, lets proceed with the data

# %% [markdown]
# lets check there are any null values in a dataset

# %%
data.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# there are no null values lets check with the heatmap also

# %%
sns.heatmap(data.isnull(), annot = True)

# %%
data["Country"].value_counts()
# Out:
# Singapore                 1
# Slovakia                  1
# South Africa              1
# Austria                   1
# Bosnia and Herzegovina    1
#                          ..
# El Salvador               1
# Uruguay                   1
# Estonia                   1
# Macedonia                 1
# Belarus                   1
# Name: Country, Length: 158, dtype: int64

# %%
data["Region"].value_counts()
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64

# %%
data.head(5)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %% [markdown]
# lets do some analysis

# %%
data.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %% [markdown]
# most happiest country is switzerland with happiness score is 7.587
# least happest counry is Togo with happiness score is 2.839

# %%
data.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=158, step=1)

# %% [markdown]
# I am creating a dummy data frame to make analysis f the data frame

# %%
df2 = pd.read_csv("happiness_score_dataset.csv", index_col="Country")

# %%
df2.head()
# Out:
#                      Region  Happiness Rank  Happiness Score  Standard Error  \
# Country
# Switzerland  Western Europe               1            7.587         0.03411
# Iceland      Western Europe               2            7.561         0.04884
# Denmark      Western Europe               3            7.527         0.03328
# Norway       Western Europe               4            7.522         0.03880
# Canada        North America               5            7.427         0.03553
#
#              Economy (GDP per Capita)   Family  Health (Life Expectancy)  \
# Country
# Switzerland                   1.39651  1.34951                   0.94143
# Iceland                       1.30232  1.40223                   0.94784
# Denmark                       1.32548  1.36058                   0.87464
# Norway                        1.45900  1.33095                   0.88521
# Canada                        1.32629  1.32261                   0.90563
#
# ...

# %%
df2.loc[["India","China","Japan"], "Happiness Rank"]
# Out:
# Country
# India    117
# China     84
# Japan     46
# Name: Happiness Rank, dtype: int64

# %% [markdown]
# Now lets continue with origina data

# %% [markdown]
# I am converting happiness rank datatype t make thing pretty easy

# %%
data["Happiness Rank"] = data["Happiness Rank"].astype("float")

# %%
data["Country"].value_counts().plot.line()

# %% [markdown]
# make no sence with the univariate data

# %%
sns.pairplot(data)

# %%
sns.scatterplot(y = "Happiness Rank", x = "Economy (GDP per Capita)", hue = "Health (Life Expectancy)", data = data)
plt.title("Rank vs (Economy&Health)")
# Out:
# Text(0.5, 1.0, 'Rank vs (Economy&Health)')

# %% [markdown]
# As we can see from the scatterplot we can see that as Happiness rank increases health is also increases and gdp also increases by increasing the rank

# %%
sns.scatterplot(y = "Happiness Rank", x = "Freedom", hue = "Trust (Government Corruption)", data = data)
plt.title("Rank vs (Freedom & Trust)")
# Out:
# Text(0.5, 1.0, 'Rank vs (Freedom & Trust)')

# %%
sns.scatterplot(y = "Happiness Rank", x = "Standard Error", hue = ("Generosity"), data = data)
plt.title("Rank vs (standard error & Generosity)")
# Out:
# Text(0.5, 1.0, 'Rank vs (standard error & Generosity)')

# %% [markdown]
# As the rank increasesgenerosity also increased

# %% [markdown]
# As the rank increases the corruption decreases and also freedom increases

# %% [markdown]
# As we can usee there is no much use with the name and egion so we will drop them

# %%
data.drop(columns=["Country", "Region"],axis = 1, inplace = True)

# %%
data.head()
# Out:
#    Happiness Rank  Happiness Score  Standard Error  Economy (GDP per Capita)  \
# 0             1.0            7.587         0.03411                   1.39651
# 1             2.0            7.561         0.04884                   1.30232
# 2             3.0            7.527         0.03328                   1.32548
# 3             4.0            7.522         0.03880                   1.45900
# 4             5.0            7.427         0.03553                   1.32629
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.34951                   0.94143  0.66557                        0.41978
# 1  1.40223                   0.94784  0.62877                        0.14145
# 2  1.36058                   0.87464  0.64938                        0.48357
# 3  1.33095                   0.88521  0.66973                        0.36503
# 4  1.32261                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# ...

# %%
data.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
sns.heatmap(data.corr(), annot = True, cmap="Purples")

# %% [markdown]
# Health score and heath ranks are highy corellated, lets handle highly correlated values with pearson correlation mmethod

# %%
#with this following function we can remove highly correlated values 
def corellation(dataset, threshold):
    col_corr = set() #set of all correlated values
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j] > threshold):
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
corr_fea = corellation(data, 0.7)
print(len(set(corr_fea)))
print(corr_fea)
# Out:
# 3
# {'Economy (GDP per Capita)', 'Health (Life Expectancy)', 'Family'}

# %% [markdown]
# By the above heatplot we can see that there are 3 high corellated value both postievely we are going to drop them because having them also thy are just acts as dupicate values
# do let''s drop them

# %%
data.drop(corr_fea, axis = 1,inplace = True)

# %%
data.sample(5)
# Out:
#      Happiness Rank  Happiness Score  Standard Error  Freedom  \
# 29             30.0            6.574         0.04612  0.44974
# 138           139.0            3.989         0.06682  0.41466
# 155           156.0            3.006         0.05015  0.15684
# 118           119.0            4.518         0.07331  0.24425
# 102           103.0            4.839         0.04337  0.33916
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 29                         0.08484     0.11451            2.83600
# 138                        0.11686     0.12388            1.68135
# 155                        0.18906     0.47179            0.32858
# 118                        0.17175     0.46187            2.24173
# 102                        0.04582     0.21854            1.57059

# %% [markdown]
# lets divide the data into train and test

# %%
x = data.drop(["Happiness Score"], axis = 1)
y = data["Happiness Score"]

# %%
x.shape,y.shape
# Out:
# ((158, 6), (158,))

# %% [markdown]
# After dividing the data we will check the skewnwss of the data

# %%
x.skew()
# Out:
# Happiness Rank                   0.000418
# Standard Error                   1.983439
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# After checking the skewnwss we are reducing the skewnes

# %%
for i in x.columns:
    if x[i].skew() > 0.5:
        x[i] = np.sqrt(x[i])
    if x[i].skew() < -0.5:
        x[i] = np.sqrt(x[i])
x.skew()
# Out:
# Happiness Rank                   0.000418
# Standard Error                   1.225889
# Freedom                         -0.413462
# Trust (Government Corruption)    0.507663
# Generosity                      -0.130961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
for i in x:
    sns.distplot(x[i])
    plt.show()

# %% [markdown]
# Now we are scalling the data into minmaxscalar

# %%
from sklearn.preprocessing import MinMaxScaler
scalar = MinMaxScaler()
x = pd.DataFrame(scalar.fit_transform(x),columns=x.columns)
x
# Out:
#      Happiness Rank  Standard Error   Freedom  Trust (Government Corruption)  \
# 0          0.000000        0.208235  0.993789                       0.872121
# 1          0.006369        0.363335  0.938841                       0.506253
# 2          0.012739        0.198578  0.969615                       0.936042
# 3          0.019108        0.260727  1.000000                       0.813261
# 4          0.025478        0.224490  0.945112                       0.772751
# ..              ...             ...       ...                            ...
# 153        0.974522        0.214341  0.883953                       1.000000
# 154        0.980892        0.236077  0.723426                       0.380962
# 155        0.987261        0.375912  0.234184                       0.585283
# 156        0.993631        0.676224  0.176937                       0.426980
# 157        1.000000        0.527227  0.544294                       0.440947
#
#      Generosity  Dystopia Residual
# ...

# %% [markdown]
# Importing certain models for model creation and prediction

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.model_selection import train_test_split, KFold, cross_val_score, GridSearchCV
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Here we are using Kfold methos to find the accuracy of the model and we are going to select best model for further evaluation

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.30, random_state = 100)

# %%
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((110, 6), (110,), (48, 6), (48,))

# %%
lr = LinearRegression()
l = Lasso()
r = Ridge()

# %%
models = []
models.append(('linear regression', LinearRegression()))
models.append(('lasso', Lasso()))
models.append(('ridge', Ridge()))


results = []
names = []

for name, model in models:
    kfold = KFold(n_splits=10, random_state=seed)
    cv_results = cross_val_score(model, x_train, y_train, cv=kfold, scoring='r2')
    
    results.append(cv_results)
    names.append(name)
    
    msg = '%s: %f, %f' % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# linear regression: 0.981550, 0.006655
# lasso: -0.133536, 0.181797
# ridge: 0.967230, 0.012052

# %% [markdown]
# By th result we can say that Linearregression and ridge is performing well

# %%
lr.fit(x_train,y_train)
print("score :", lr.score(x_train,y_train)*100)
predlr = lr.predict(x_test)
print(predlr)

print("r2 score is :", r2_score(y_test, predlr))
print("MSE :",mean_squared_error(y_test, predlr))
print("MAE :",mean_absolute_error(y_test, predlr))
print("\n")

plt.scatter(predlr, y_test)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)
plt.ylabel("True")
plt.xlabel("Predicted")
plt.title("Linear Regression")
plt.show()
# Out:
# score : 98.66377113044118
# [6.17421844 7.09982334 4.2578374  7.00338579 7.21481312 4.55066779
#  4.97971626 7.30409122 4.74557116 6.07470516 6.57410127 5.49441739
#  6.65546003 6.59918059 4.84878037 5.07294987 6.31240554 6.20169712
#  5.8196452  3.56366991 5.93375337 6.53027932 5.11740831 3.77731433
#  6.13822101 3.41890014 4.41973968 6.88636426 6.63598709 5.44910366
#  4.24443639 3.90450747 4.71506028 4.14940484 7.05516089 6.94396153
#  5.708966   4.18416512 3.99634401 4.39345749 3.75827487 4.38006317
#  4.45124005 4.84291395 4.83287273 3.7523528  5.26552056 6.37944212]
# r2 score is : 0.9853620037718187
# MSE : 0.019633851836855655
# MAE : 0.10525566991234465

# %%
r.fit(x_train,y_train)
print("score :", r.score(x_train,y_train)*100)
predr = lr.predict(x_test)
print(predr)
print("r2 score is :", r2_score(y_test, predr))
print("MSE :",mean_squared_error(y_test, predr))
print("MAE :",mean_absolute_error(y_test, predr))
print("\n")

plt.scatter(predr, y_test)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)
plt.ylabel("True")
plt.xlabel("Predicted")
plt.title("Ridge Regression")
plt.show()
# Out:
# score : 97.56741480607762
# [6.17421844 7.09982334 4.2578374  7.00338579 7.21481312 4.55066779
#  4.97971626 7.30409122 4.74557116 6.07470516 6.57410127 5.49441739
#  6.65546003 6.59918059 4.84878037 5.07294987 6.31240554 6.20169712
#  5.8196452  3.56366991 5.93375337 6.53027932 5.11740831 3.77731433
#  6.13822101 3.41890014 4.41973968 6.88636426 6.63598709 5.44910366
#  4.24443639 3.90450747 4.71506028 4.14940484 7.05516089 6.94396153
#  5.708966   4.18416512 3.99634401 4.39345749 3.75827487 4.38006317
#  4.45124005 4.84291395 4.83287273 3.7523528  5.26552056 6.37944212]
# r2 score is : 0.9853620037718187
# MSE : 0.019633851836855655
# MAE : 0.10525566991234465

# %%
#As we know Vanilla linear regression doesn't have any hyperparameters. 
#But variants of linear regression do. Ridge regression and lasso both add a regularization term to linear regression 
#the weight for the regularization term is called the regularization parameter.

# %% [markdown]
# so we can see that best model is linear regression

# %% [markdown]
# Let's predict with test data

# %%
import joblib

# %%
joblib.dump(lr ,"Happiness.pk1")
# Out:
# ['Happiness.pk1']

# %%
model = joblib.load("Happiness.pk1")

# %%
testdata = pd.read_csv("Test_happiness_Dataset.csv")

# %%
testdata.sample(5)
# Out:
#            Country                           Region  Happiness Rank  \
# 4   United Kingdom                   Western Europe              21
# 50          Cyprus                   Western Europe              67
# 53    Turkmenistan       Central and Eastern Europe              70
# 22          Kuwait  Middle East and Northern Africa              39
# 32         Bahrain  Middle East and Northern Africa              49
#
#     Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 4             6.867         0.01866                   1.26637  1.28548
# 50            5.689         0.05580                   1.20813  0.89318
# 53            5.548         0.04175                   0.95847  1.22668
# 22            6.295         0.04456                   1.55422  1.16594
# 32            5.960         0.05412                   1.32376  1.21624
#
#     Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %%
testdata = testdata.drop(columns = ["Country", "Region", "Family", "Economy (GDP per Capita)", "Health (Life Expectancy)", "Happiness Score"],axis = 1)

# %%
testdata.head(5)
# Out:
#    Happiness Rank  Standard Error  Freedom  Trust (Government Corruption)  \
# 0              17         0.03499  0.61583                        0.37798
# 1              18         0.03676  0.61777                        0.28703
# 2              19         0.03595  0.58450                        0.22540
# 3              20         0.03729  0.64157                        0.38583
# 4              21         0.01866  0.59625                        0.32067
#
#    Generosity  Dystopia Residual
# 0     0.28034            1.96961
# 1     0.45901            1.97570
# 2     0.22250            2.41484
# 3     0.26428            2.24743
# 4     0.51912            1.96994

# %%
from sklearn.preprocessing import MinMaxScaler
minmax = MinMaxScaler()
new_data = pd.DataFrame(minmax.fit_transform(testdata),columns=testdata.columns)
new_data.sample(5)
# Out:
#     Happiness Rank  Standard Error   Freedom  Trust (Government Corruption)  \
# 15        0.254237        0.227184  0.877268                       0.470388
# 26        0.440678        0.285015  0.818161                       0.181428
# 48        0.813559        1.000000  0.654241                       0.044035
# 32        0.542373        0.300886  0.542953                       0.586117
# 58        0.983051        0.106290  0.856629                       0.199989
#
#     Generosity  Dystopia Residual
# 15    0.401194           0.657121
# 26    0.475179           0.823115
# 48    0.366196           0.656711
# 32    0.298846           0.427147
# 58    0.290105           0.609944

# %%
prediction = model.predict(new_data)

# %%
happiness_submission = pd.DataFrame({'index': testdata.index,"prediction": prediction})

# %%
happiness_submission.to_csv("happiness_submission.csv")
